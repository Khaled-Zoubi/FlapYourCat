# %% [markdown]
# <a href="https://colab.research.google.com/github/Khaled-Zoubi/FlapYourCat/blob/main/playground_x.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Khaled-Zoubi/FlapYourCat
# Out:
# fatal: destination path 'FlapYourCat' already exists and is not an empty directory.

# %%
# %cd /content/FlapYourCat
# Out:
# /content/FlapYourCat

# %%
# !pwd
# Out:
# /content/FlapYourCat

# %%
# !git status
# Out:
# On branch main
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git pull
# Out:
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 840 bytes | 840.00 KiB/s, done.
# From https://github.com/Khaled-Zoubi/FlapYourCat
#  * [new branch]      main       -> origin/main

# %%
# %mkdir notebooks
